# %%
import os
from pathlib import Path
from Replay import Replay

# %%
base_path = Path('replay_files')
file = "SILLY716-11-2023 9-14-49 PM.txt"

# %%
replay = Replay(base_path / file)
print("Done")
# Out:
# [INFO] Reading Replay json replay_files\SILLY716-11-2023 9-14-49 PM.txt
# Done

# %%
for player in replay.players_stats:
    if 'gorilla' in player.name.lower():
        continue
    print(player.name)
    player.plot_all()
# Out:
# QUIETWEBBY
# TTT
# DEEZ
# NUTS
# SILLY
# SKINK
# SKINK
# N4NO
